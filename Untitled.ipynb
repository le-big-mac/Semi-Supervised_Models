# %%
import torch
from torch import nn
from torchviz import make_dot

# %%
model = nn.Sequential()
model.add_module('W0', nn.Linear(500, 200))
model.add_module('re', nn.ReLU())

x = torch.randn(1,500)
make_dot(model(x), params=dict(model.named_parameters()))
